# %%
import pandas as pd
import numpy as np

# %%
data  = pd.read_excel('Yield Statistics_Wheat production in 4 countries.xls')

# %%
data
# Out:
#       Year   Unnamed: 1 Germany Harvested Area (ha)   Unnamed: 3   Unnamed: 4  \
# 0      NaN  Replicate 1                 Replicate 2  Replicate 3  Replicate 1
# 1   1962.0      1742445                     1742275      1742480      5906340
# 2   1963.0      1808256                     1808086      1808291      6135856
# 3   1964.0      1880123                     1879953      1880158      6551073
# 4   1965.0      1902641                     1902471      1902676      6149217
# 5   1966.0      1872885                     1872715      1872920      6053835
# 6   1967.0      1947186                     1947016      1947221      7830490
# 7   1968.0      2033901                     2033731      2033936      8574959
# 8   1969.0      2054537                     2054367      2054572      7987036
# 9   1970.0      2091605                     2091435      2091640      7793912
# 10  1971.0      2177729                     2177559      2177764      9631647
# ...

# %%
data.isnull().sum()
# Out:
# Year                                             1
# Unnamed: 1                                       0
# Germany Harvested Area (ha)                      0
# Unnamed: 3                                       0
# Unnamed: 4                                       0
# Germany Production (tonnes)                      0
# Unnamed: 6                                       0
# Unnamed: 7                                      58
# United States of America Harvested Area (ha)     0
# Unnamed: 9                                       0
# Unnamed: 10                                      0
# United States of America Production (tonnes)     0
# Unnamed: 12                                      0
# Unnamed: 13                                      0
# Unnamed: 14                                     58
# Unnamed: 15                                      0
# Egypt Harvested Area (ha)                        0
# Unnamed: 17                                      0
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.dropna(inplace=True,axis=1)

# %%
data
# Out:
#      Unnamed: 1 Germany Harvested Area (ha)   Unnamed: 3   Unnamed: 4  \
# 0   Replicate 1                 Replicate 2  Replicate 3  Replicate 1
# 1       1742445                     1742275      1742480      5906340
# 2       1808256                     1808086      1808291      6135856
# 3       1880123                     1879953      1880158      6551073
# 4       1902641                     1902471      1902676      6149217
# 5       1872885                     1872715      1872920      6053835
# 6       1947186                     1947016      1947221      7830490
# 7       2033901                     2033731      2033936      8574959
# 8       2054537                     2054367      2054572      7987036
# 9       2091605                     2091435      2091640      7793912
# 10      2177729                     2177559      2177764      9631647
# 11      2315924                     2315754      2315959      9351464
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 1                                      0
# Germany Harvested Area (ha)                     0
# Unnamed: 3                                      0
# Unnamed: 4                                      0
# Germany Production (tonnes)                     0
# Unnamed: 6                                      0
# United States of America Harvested Area (ha)    0
# Unnamed: 9                                      0
# Unnamed: 10                                     0
# United States of America Production (tonnes)    0
# Unnamed: 12                                     0
# Unnamed: 13                                     0
# Unnamed: 15                                     0
# Egypt Harvested Area (ha)                       0
# Unnamed: 17                                     0
# Unnamed: 18                                     0
# Egypt Production (tonnes)                       0
# Unnamed: 20                                     0
# Unnamed: 22                                     0
# ...

# %%
plt.scatter(data.Year,data['Germany Harvested Area (ha)'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [127], in <cell line: 1>()
# ----> 1 plt.scatter(data.Year,data['Germany Harvested Area (ha)'])
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Year'

# %%
X = data.Year
y = data[list(data.columns)[1:]]

# %%
X.isnull().sum()
# Out:
# 1

# %%
X.dropna(inplace=True,axis=0)

# %%
X
# Out:
# 1     1962.0
# 2     1963.0
# 3     1964.0
# 4     1965.0
# 5     1966.0
# 6     1967.0
# 7     1968.0
# 8     1969.0
# 9     1970.0
# 10    1971.0
# 11    1972.0
# 12    1973.0
# 13    1974.0
# 14    1975.0
# 15    1976.0
# 16    1977.0
# 17    1978.0
# 18    1979.0
# 19    1980.0
# 20    1981.0
# 21    1982.0
# 22    1983.0
# 23    1984.0
# 24    1985.0
# 25    1986.0
# 26    1987.0
# 27    1988.0
# 28    1989.0
# 29    1990.0
# 30    1991.0
# 31    1992.0
# 32    1993.0
# 33    1994.0
# 34    1995.0
# 35    1996.0
# 36    1997.0
# 37    1998.0
# 38    1999.0
# 39    2000.0
# 40    2001.0
# 41    2002.0
# 42    2003.0
# 43    2004.0
# 44    2005.0
# 45    2006.0
# 46    2007.0
# 47    2008.0
# 48    2009.0
# 49    2010.0
# 50    2011.0
# 51    2012.0
# 52    2013.0
# 53    2014.0
# 54    2015.0
# 55    2016.0
# 56    2017.0
# 57    2018.0
# Name: Year, dtype: float64

# %%
y.isnull().sum()
# Out:
# Unnamed: 1                                       0
# Germany Harvested Area (ha)                      0
# Unnamed: 3                                       0
# Unnamed: 4                                       0
# Germany Production (tonnes)                      0
# Unnamed: 6                                       0
# Unnamed: 7                                      58
# United States of America Harvested Area (ha)     0
# Unnamed: 9                                       0
# Unnamed: 10                                      0
# United States of America Production (tonnes)     0
# Unnamed: 12                                      0
# Unnamed: 13                                      0
# Unnamed: 14                                     58
# Unnamed: 15                                      0
# Egypt Harvested Area (ha)                        0
# Unnamed: 17                                      0
# Unnamed: 18                                      0
# ...

# %%
y.dropna(inplace=True,axis=1)
# Out:
# C:\Users\iam18\AppData\Local\Temp\ipykernel_4840\3155359153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y.dropna(inplace=True,axis=1)

# %%
y
# Out:
#      Unnamed: 1 Germany Harvested Area (ha)   Unnamed: 3   Unnamed: 4  \
# 0   Replicate 1                 Replicate 2  Replicate 3  Replicate 1
# 1       1742445                     1742275      1742480      5906340
# 2       1808256                     1808086      1808291      6135856
# 3       1880123                     1879953      1880158      6551073
# 4       1902641                     1902471      1902676      6149217
# 5       1872885                     1872715      1872920      6053835
# 6       1947186                     1947016      1947221      7830490
# 7       2033901                     2033731      2033936      8574959
# 8       2054537                     2054367      2054572      7987036
# 9       2091605                     2091435      2091640      7793912
# 10      2177729                     2177559      2177764      9631647
# 11      2315924                     2315754      2315959      9351464
# ...

# %%
data.drop(['Unnamed: 1','Unnamed: 3','Unnamed: 4','Unnamed: 6','Unnamed: 7','Unnamed: 10','Unnamed: 9','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 17','Unnamed: 18','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 24','Unnamed: 25','Unnamed: 27'],inplace=True,axis=1)

# %%
data.drop(['Unnamed: 9'],inplace=True,axis=1)

# %%
data
# Out:
#       Year Germany Harvested Area (ha) Germany Production (tonnes)  \
# 0      NaN                 Replicate 2                 Replicate 2
# 1   1962.0                     1742275                     5906510
# 2   1963.0                     1808086                     6136026
# 3   1964.0                     1879953                     6551243
# 4   1965.0                     1902471                     6149387
# 5   1966.0                     1872715                     6054005
# 6   1967.0                     1947016                     7830660
# 7   1968.0                     2033731                     8575129
# 8   1969.0                     2054367                     7987206
# 9   1970.0                     2091435                     7794082
# 10  1971.0                     2177559                     9631817
# 11  1972.0                     2315754                     9351634
# 12  1973.0                     2298921                     9995702
# ...

# %%
X = data.Year
y= data[list(data.columns)[1:]]

# %%
data
# Out:
#       Year Germany Harvested Area (ha) Germany Production (tonnes)  \
# 0      NaN                 Replicate 2                 Replicate 2
# 1   1962.0                     1742275                     5906510
# 2   1963.0                     1808086                     6136026
# 3   1964.0                     1879953                     6551243
# 4   1965.0                     1902471                     6149387
# 5   1966.0                     1872715                     6054005
# 6   1967.0                     1947016                     7830660
# 7   1968.0                     2033731                     8575129
# 8   1969.0                     2054367                     7987206
# 9   1970.0                     2091435                     7794082
# 10  1971.0                     2177559                     9631817
# 11  1972.0                     2315754                     9351634
# 12  1973.0                     2298921                     9995702
# ...

# %%
X.dropna(inplace=True,axis=0)
X.head()
# Out:
# 1    1962.0
# 2    1963.0
# 3    1964.0
# 4    1965.0
# 5    1966.0
# Name: Year, dtype: float64

# %%
y.isnull().sum()
# Out:
# Germany Harvested Area (ha)                     0
# Germany Production (tonnes)                     0
# United States of America Harvested Area (ha)    0
# United States of America Production (tonnes)    0
# Egypt Harvested Area (ha)                       0
# Egypt Production (tonnes)                       0
# India Harvested Area (ha)                       0
# India Production (tonnes)                       0
# dtype: int64

# %%
plt.scatter(X,data['Germany Harvested Area (ha)'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Germany Harvested Area (ha) '
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
y.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 1, Germany Harvested Area (ha), Unnamed: 3, Unnamed: 4, Germany Production (tonnes), Unnamed: 6, Unnamed: 7, United States of America Harvested Area (ha), Unnamed: 9, Unnamed: 10, United States of America Production (tonnes), Unnamed: 12, Unnamed: 13, Unnamed: 14, Unnamed: 15, Egypt Harvested Area (ha), Unnamed: 17, Unnamed: 18, Egypt Production (tonnes), Unnamed: 20, Unnamed: 21, Unnamed: 22, India Harvested Area (ha), Unnamed: 24, Unnamed: 25, India Production (tonnes), Unnamed: 27]
# Index: []
#
# [0 rows x 27 columns]

# %%
plt.plot(X,data['Germany Production (tonnes)'],'bo')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [95], in <cell line: 1>()
# ----> 1 plt.plot(X,data['Germany Production (tonnes)'],'bo')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
# ...

# %%
y.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data.corr(data.Year,data['Germany Production (tonnes)'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [101], in <cell line: 1>()
# ----> 1 data.corr(data.Year,data['Germany Production (tonnes)'])
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:9533, in DataFrame.corr(self, method, min_periods)
#    9530 idx = cols.copy()
#    9531 mat = numeric_df.to_numpy(dtype=float, na_value=np.nan, copy=False)
# -> 9533 if method == "pearson":
#    9534     correl = libalgos.nancorr(mat, minp=min_periods)
#    9535 elif method == "spearman":
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ...

# %%
data.columns
# Out:
# Index(['Year', 'Germany Harvested Area (ha)', 'Germany Production (tonnes)',
#        'United States of America Harvested Area (ha)',
#        'United States of America Production (tonnes)',
#        'Egypt Harvested Area (ha)', 'Egypt Production (tonnes)',
#        'India Harvested Area (ha)', 'India Production (tonnes)'],
#       dtype='object')

# %%
plt.scatter(x=X,y=data['Germany Production (tonnes)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [105], in <cell line: 1>()
# ----> 1 plt.scatter(x=X,y=data['Germany Production (tonnes)'])
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2807, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2802 @_copy_docstring_and_deprecators(Axes.scatter)
#    2803 def scatter(
#    2804         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
# ...

# %%
data = data.Year.dropna(inplace=True,axis=0)

# %%
data

# %%
data
# Out:
#       Year   Unnamed: 1 Germany Harvested Area (ha)   Unnamed: 3   Unnamed: 4  \
# 0      NaN  Replicate 1                 Replicate 2  Replicate 3  Replicate 1
# 1   1962.0      1742445                     1742275      1742480      5906340
# 2   1963.0      1808256                     1808086      1808291      6135856
# 3   1964.0      1880123                     1879953      1880158      6551073
# 4   1965.0      1902641                     1902471      1902676      6149217
# 5   1966.0      1872885                     1872715      1872920      6053835
# 6   1967.0      1947186                     1947016      1947221      7830490
# 7   1968.0      2033901                     2033731      2033936      8574959
# 8   1969.0      2054537                     2054367      2054572      7987036
# 9   1970.0      2091605                     2091435      2091640      7793912
# 10  1971.0      2177729                     2177559      2177764      9631647
# ...

# %%
X = data.Year
y = data[list(data.columns)[1:]]

# %%
X.dropna(inplace=True,axis=0)

# %%
X
# Out:
# 1     1962.0
# 2     1963.0
# 3     1964.0
# 4     1965.0
# 5     1966.0
# 6     1967.0
# 7     1968.0
# 8     1969.0
# 9     1970.0
# 10    1971.0
# 11    1972.0
# 12    1973.0
# 13    1974.0
# 14    1975.0
# 15    1976.0
# 16    1977.0
# 17    1978.0
# 18    1979.0
# 19    1980.0
# 20    1981.0
# 21    1982.0
# 22    1983.0
# 23    1984.0
# 24    1985.0
# 25    1986.0
# 26    1987.0
# 27    1988.0
# 28    1989.0
# 29    1990.0
# 30    1991.0
# 31    1992.0
# 32    1993.0
# 33    1994.0
# 34    1995.0
# 35    1996.0
# 36    1997.0
# 37    1998.0
# 38    1999.0
# 39    2000.0
# 40    2001.0
# 41    2002.0
# 42    2003.0
# 43    2004.0
# 44    2005.0
# 45    2006.0
# 46    2007.0
# 47    2008.0
# 48    2009.0
# 49    2010.0
# 50    2011.0
# 51    2012.0
# 52    2013.0
# 53    2014.0
# 54    2015.0
# 55    2016.0
# 56    2017.0
# 57    2018.0
# Name: Year, dtype: float64

# %%
y.drop(['Unnamed: 1','Unnamed: 3','Unnamed: 4','Unnamed: 6','Unnamed: 7','Unnamed: 9','Unnamed: 10','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 17','Unnamed: 18','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 24','Unnamed: 25','Unnamed: 27'],inplace=True,axis=1)
# Out:
# C:\Users\iam18\AppData\Local\Temp\ipykernel_4840\4168166983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y.drop(['Unnamed: 1','Unnamed: 3','Unnamed: 4','Unnamed: 6','Unnamed: 7','Unnamed: 9','Unnamed: 10','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 17','Unnamed: 18','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 24','Unnamed: 25','Unnamed: 27'],inplace=True,axis=1)

# %%
import matplotlib.pyplot as plt

# %%
y = y.drop(0)

# %%
y
# Out:
#    Germany Harvested Area (ha) Germany Production (tonnes)  \
# 1                      1742275                     5906510
# 2                      1808086                     6136026
# 3                      1879953                     6551243
# 4                      1902471                     6149387
# 5                      1872715                     6054005
# 6                      1947016                     7830660
# 7                      2033731                     8575129
# 8                      2054367                     7987206
# 9                      2091435                     7794082
# 10                     2177559                     9631817
# 11                     2315754                     9351634
# 12                     2298921                     9995702
# 13                     2359422                    10914619
# 14                     2257400                     9749881
# 15                     2393251                     9416640
# ...

# %%
y.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
y['Germany Harvested Area (ha)'].corr(y['Germany Production (tonnes)'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [185], in <cell line: 1>()
# ----> 1 y['Germany Harvested Area (ha)'].corr(y['Germany Production (tonnes)'])
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:2557, in Series.corr(self, other, method, min_periods)
#    2554     return np.nan
#    2556 if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2557     return nanops.nancorr(
#    2558         this.values, other.values, method=method, min_periods=min_periods
#    2559     )
#    2561 raise ValueError(
#    2562     "method must be either 'pearson', "
#    2563     "'spearman', 'kendall', or a callable, "
#    2564     f"'{method}' was supplied"
#    2565 )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split,cross_val_score,cross_val_predict

# %%
model = LinearRegression()

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=.30,random_state=42)  
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [191], in <cell line: 1>()
# ----> 1 X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=.30,random_state=42)
#       2 model.fit(X_train,y_train)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2417, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2414 if n_arrays == 0:
#    2415     raise ValueError("At least one array required as input")
# -> 2417 arrays = indexable(*arrays)
#    2419 n_samples = _num_samples(arrays[0])
#    2420 n_train, n_test = _validate_shuffle_split(
#    2421     n_samples, test_size, train_size, default_test_size=0.25
#    2422 )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:378, in indexable(*iterables)
#     359 """Make arrays indexable for cross-validation.
#     360
# ...

# %%
pred = model.predict(X)
pred
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Input In [192], in <cell line: 1>()
# ----> 1 pred = model.predict(X)
#       2 pred
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:362, in LinearModel.predict(self, X)
#     348 def predict(self, X):
#     349     """
#     350     Predict using the linear model.
#     351
#    (...)
#     360         Returns predicted values.
#     361     """
# --> 362     return self._decision_function(X)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:343, in LinearModel._decision_function(self, X)
#     342 def _decision_function(self, X):
# --> 343     check_is_fitted(self)
#     345     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...
